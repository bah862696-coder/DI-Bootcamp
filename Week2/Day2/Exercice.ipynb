# %%
# !pip install kaggle

# %%
import kaggle

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import kaggle.json
#
# ModuleNotFoundError: No module named 'kaggle.json'
